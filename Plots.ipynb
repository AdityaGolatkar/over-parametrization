# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
#matplotlib.rcParams.update({'font.size': 22})
import seaborn as sns
sns.set_style("darkgrid")

# %%
nunits = [8,16,32,64,128,256,512,1024,2048,4096,8192,16348]

# %% [markdown]
# # Layer 1

# %%
fro = [15.5,
20.7,
9.21,
8.23,
9.13,
11.1,
14.4,
19.4,
26.7,
37.4,
52.5,
74.1]

# %%
dist=[15.4,
20.6,
8.71,
6.84,
6.3,
5.93,
5.66,
5.26,
4.79,
4.23,
3.46,
2.56]

# %%
spec=[
6.69,
6.55,
2.39,
2,
1.9,
1.8,
1.84,
1.8,
1.89,
2.07,
2.4,
2.95
]

# %%
plt.plot(nunits,fro,label='Frobenius',marker='o')
plt.plot(nunits,dist,label='Distance',marker='o')
plt.plot(nunits,spec,label='Spectral',marker='o')
plt.xlabel('Number of hidden units')
plt.ylabel('Measure')
plt.title('first layer')
plt.xscale('log',basex=2)
plt.gca().legend()
plt.savefig('first_layer.jpg')
plt.show()

# %% [markdown]
# # Layer 2

# %%
fro = [5.47,
11.4,
8.27,
7.87,
8.94,
10.9,
14.3,
19.3,
26.7,
37.4,
52.5,
74.1]

# %%
dist=[4.83,
10.2,
6.28,
5.01,
4.63,
4.49,
4.5,
4.52,
4.56,
4.61,
4.57,
4.42]

# %%
spec=[
3,
5.19,
3.17,
2.8,
2.61,
2.6,
2.5,
2.46,
2.4,
2.29,
2.26,
2.14]

# %%
plt.plot(nunits,fro,label='Frobenius',marker='o')
plt.plot(nunits,dist,label='Distance',marker='o')
plt.plot(nunits,spec,label='Spectral',marker='o')
plt.xlabel('Number of hidden units')
plt.ylabel('Measure')
plt.title('second layer')
plt.xscale('log',basex=2)
plt.gca().legend()
plt.savefig('second_layer.jpg')
plt.show()

# %% [markdown]
# # Layer 3

# %%
fro = [5.14,
9.18,
7.53,
6.56,
6.3,
6.1,
6.05,
5.93,
5.85,
5.76,
5.56,
5.28]

# %%
dist=[4.7,
8.3,
6.39,
5.23,
5,
4.8,
4.77,
4.7,
4.64,
4.57,
4.39,
4.11]

# %%
spec=[
3.29,
4.58,
3.38,
2.94,
2.72,
2.63,
2.53,
2.49,
2.45,
2.39,
2.26,
2.14]

# %%
plt.plot(nunits,fro,label='Frobenius',marker='o')
plt.plot(nunits,dist,label='Distance',marker='o')
plt.plot(nunits,spec,label='Spectral',marker='o')
plt.xlabel('Number of hidden units')
plt.ylabel('Measure')
plt.title('third layer')
plt.xscale('log',basex=2)
plt.gca().legend()
plt.savefig('third_layer.jpg')
plt.show()

# %% [markdown]
# # My bound

# %%
mb = [
399,
1990,
443,
248,
206,
186,
182,
172,
165,
158,
144,
127    
]

# %%
plt.plot(nunits,mb,marker='o')
plt.xlabel('Number of hidden units')
plt.ylabel('Measure')
plt.title('overall')
plt.xscale('log',basex=2)
plt.savefig('my_bound.jpg')
plt.show()

# %% [markdown]
# # Errors
